# %% [markdown]
# # Bank marketing campaigns dataset analysis # Opening a Term Deposit
# ### It is a dataset that describing Portugal bank marketing campaigns results.
# ### Conducted campaigns were based mostly on direct phone calls, offering bank client to place a term deposit.
# ### If after all marking afforts client had agreed to place deposit - target variable marked 'yes', otherwise 'no'

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # General info about data

# %%
data=pd.read_csv('bank-additional-full.csv',sep=';')
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
data.nunique()
# Out:
# age                 78
# job                 12
# marital              4
# education            8
# default              3
# housing              3
# loan                 3
# contact              2
# month               10
# day_of_week          5
# duration          1544
# campaign            42
# pdays               27
# previous             8
# poutcome             3
# emp.var.rate        10
# cons.price.idx      26
# cons.conf.idx       26
# euribor3m          316
# nr.employed         11
# y                    2
# dtype: int64

# %%
data.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
data['nr.employed'].head(20)
# Out:
# 0     5191.0
# 1     5191.0
# 2     5191.0
# 3     5191.0
# 4     5191.0
# 5     5191.0
# 6     5191.0
# 7     5191.0
# 8     5191.0
# 9     5191.0
# 10    5191.0
# 11    5191.0
# 12    5191.0
# 13    5191.0
# 14    5191.0
# 15    5191.0
# 16    5191.0
# 17    5191.0
# 18    5191.0
# 19    5191.0
# Name: nr.employed, dtype: float64

# %% [markdown]
# # data visualization

# %%
sns.heatmap(data=pd.isnull(data))#there is no null value..
# Out:
# <AxesSubplot:>

# %% [markdown]
# # visualization

# %%
data=pd.get_dummies(data=data,columns=['y'],drop_first=True)

# %%
list=data.columns.to_list()
list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed',
#  'y_yes']

# %%
list.remove('y_yes')
list.remove('duration',)

# %%
for i in list:
    plt.figure(figsize=(35,5))
    ((data[data.y_yes==1][i].value_counts().sort_index()/len(data[i]))*100).plot(kind='bar',color='g')
    ((data[data.y_yes==0][i].value_counts().sort_index()/len(data[i]))*100).plot(kind='bar',color='r',alpha=0.4)
    plt.title(i)

# %%
sns.countplot(data['y_yes'])
plt.title('number of people have agreed')
# Out:
# C:\Users\HP\anaconda3\envs\panda_ground\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'number of people have agreed')

# %%
 sns.catplot(
    data=data, kind="bar",
    x="y_yes", y="day_of_week",
     palette="dark", alpha=.6, height=6
)
plt.title('the agreement of costumers due to day of week ')
# Out:
# Text(0.5, 1.0, 'the agreement of costumers due to day of week ')

# %%
 sns.catplot(
    data=data, kind="bar",
    x="y_yes", y="job",
     palette="dark", alpha=.6, height=6
)
plt.title('the agreement of costumers due to thier job')
# Out:
# Text(0.5, 1.0, 'the agreement of costumers due to thier job')

# %%
 sns.catplot(
    data=data, kind="bar",
    x="y_yes", y="month",
     palette="dark", alpha=.6, height=6
) 
plt.title('the agreement of costumers due to months')
# Out:
# Text(0.5, 1.0, 'the agreement of costumers due to months')

# %%
sns.distplot(data['age'])
plt.title('the distribution of costumers age')
# Out:
# C:\Users\HP\anaconda3\envs\panda_ground\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'the distribution of costumers age')

# %%
sns.barplot(data=data,x='month',y='y_yes',palette='deep')
# Out:
# <AxesSubplot:xlabel='month', ylabel='y_yes'>

# %%
sns.scatterplot(data=data,x='duration',y='y_yes')
plt.title('the agreement of costumers due to duration')
# Out:
# Text(0.5, 1.0, 'the agreement of costumers due to duration')

# %%
plt.figure(figsize=(35,7))
sns.violinplot(data=data,x='nr.employed',y='y_yes',palette='deep')
# Out:
# <AxesSubplot:xlabel='nr.employed', ylabel='y_yes'>

# %%
sns.relplot(data=data,x='emp.var.rate',y='cons.price.idx',hue='y_yes')

# %%
data.nunique()
# Out:
# age                 78
# job                 12
# marital              4
# education            8
# default              3
# housing              3
# loan                 3
# contact              2
# month               10
# day_of_week          5
# duration          1544
# campaign            42
# pdays               27
# previous             8
# poutcome             3
# emp.var.rate        10
# cons.price.idx      26
# cons.conf.idx       26
# euribor3m          316
# nr.employed         11
# y_yes                2
# dtype: int64

# %%
sns.barplot(data=data,x='housing',y='y_yes',hue='loan',palette='deep')
plt.title('the agreement of costumers due to costumer having or not having a house,and according to loan ')
# Out:
# Text(0.5, 1.0, 'the agreement of costumers due to costumer having or not having a house,and according to loan ')

# %%
plt.figure(figsize=(35,7))
sns.barplot(data=data,x='education',y='y_yes',hue='loan',palette='deep')
# Out:
# <AxesSubplot:xlabel='education', ylabel='y_yes'>

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### according to data visualization that i did above im going to lable and encoded some features

# %%
data=pd.get_dummies(data=data,columns=['default'],drop_first=True)

# %%
poutcome={'failure':0,'nonexistent':1,'success':2}
marital={'single':3,'married':2,'divorced':1,'unknown':0}
loan={'unknown':0,'no':2,'yes':1}
contact={'telephone':1,'cellular':0}
housing={'yes':2,'no':1,'unknown':0}
education={'university.degree':7,'high.school':6,'professional.course':5,'basic.9y':5,'unknown':4,'basic.6y':3,'basic.4y':4,'illiterate':3}
job={'unknown':0,'housemaid':0,'entrepreneur':1,'self-employed':1,'retired':2,'student':2,'services':5,'blue-collar':3,'technician':3,'admin.':4,'management':2, 'unemployed':3}
empvarrate={'-3.4':2,'-3':2,'-2.9':2,'-1.7':3,'-1.1':3,'-1.8':2,'1.4':2,'1.4':1,'-1.8':1}

# %%
data['poutcome']=data['poutcome'].map(poutcome)
data['marital']=data['marital'].map(marital)
data['loan']=data['loan'].map(loan)
data['contact']=data['contact'].map(contact)
data['housing']=data['housing'].map(housing)
data['education']=data['education'].map(education)
data['job']=data['job'].map(job)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              41188 non-null  int64
#  1   job              41188 non-null  int64
#  2   marital          41188 non-null  int64
#  3   education        41188 non-null  int64
#  4   housing          41188 non-null  int64
#  5   loan             41188 non-null  int64
#  6   contact          41188 non-null  int64
#  7   month            41188 non-null  object
#  8   day_of_week      41188 non-null  object
#  9   duration         41188 non-null  int64
#  10  campaign         41188 non-null  int64
#  11  pdays            41188 non-null  int64
#  12  previous         41188 non-null  int64
#  13  poutcome         41188 non-null  int64
#  14  emp.var.rate     41188 non-null  float64
#  15  cons.price.idx   41188 non-null  float64
#  16  cons.conf.idx    41188 non-null  float64
# ...

# %% [markdown]
# ### spreating data

# %%
x=data.drop('y_yes',axis=1)
y=data['y_yes']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train=pd.get_dummies(data=X_train,columns=['day_of_week','month'],drop_first=True)
X_test=pd.get_dummies(data=X_test,columns=['day_of_week','month'],drop_first=True)

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
s=StandardScaler()

# %%
X_train[['age','duration','pdays','cons.price.idx','cons.conf.idx','nr.employed']]=s.fit_transform(X_train[['age','duration','pdays','cons.price.idx','cons.conf.idx','nr.employed']])

# %%
X_test[['age','duration','pdays','cons.price.idx','cons.conf.idx','nr.employed']]=s.transform(X_test[['age','duration','pdays','cons.price.idx','cons.conf.idx','nr.employed']])

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
l=LogisticRegression(C=0.5)

# %%
l.fit(X_train,y_train)
# Out:
# C:\Users\HP\anaconda3\envs\panda_ground\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=0.5)

# %%
p=l.predict(X_test)

# %%
l.score(X_test,y_test) #accuracy
# Out:
# 0.9101723719349356

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
classification_report(y_test,p)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.93      0.97      0.95      7303\n           1       0.66      0.42      0.52       935\n\n    accuracy                           0.91      8238\n   macro avg       0.80      0.70      0.73      8238\nweighted avg       0.90      0.91      0.90      8238\n'

# %%
confusion_matrix(y_test,p)
# Out:
# array([[7102,  201],
#        [ 539,  396]], dtype=int64)

# %% [markdown]
# # Polynomial reg

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
p=PolynomialFeatures()

# %%
X_train=p.fit_transform(X_train)

# %%
X_test=p.fit_transform(X_test)

# %%
poly=LogisticRegression()

# %%
poly.fit(X_train,y_train)
# Out:
# C:\Users\HP\anaconda3\envs\panda_ground\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predection2=poly.predict(X_test)

# %%
poly.score(X_test,y_test)#accuracy
# Out:
# 0.9142995872784656

# %%
classification_report(y_test,predection2)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.94      0.97      0.95      7303\n           1       0.67      0.49      0.57       935\n\n    accuracy                           0.91      8238\n   macro avg       0.80      0.73      0.76      8238\nweighted avg       0.91      0.91      0.91      8238\n'

# %%
confusion_matrix(y_test,predection2)
# Out:
# array([[7073,  230],
#        [ 476,  459]], dtype=int64)
